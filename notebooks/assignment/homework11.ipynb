# %% [markdown]
# Task 1 - Reading, writing, splitting and printing words from the linked file and text.

# %%
import urllib.request

text = urllib.request.urlopen("https://drive.google.com/file/d/15brgRpgry4Q0obwtMG8KJIO9aRwyMUpr/view?usp=sharing").read().decode("utf-8")
print(text[:50])
# Out:
# <!DOCTYPE html><html><head><script nonce="P2GDj28F

# %%
words = sentence.split(" ")
